# %% [markdown]
# # Distribucion Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a = 1
b = 100
n =100000
data=np.random.uniform(a,b,n)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([10073.,  9887., 10047.,  9892.,  9843.,  9888.,  9998., 10182.,
#         10113., 10077.]),
#  array([ 1.00295156, 10.90264183, 20.8023321 , 30.70202237, 40.60171265,
#         50.50140292, 60.40109319, 70.30078346, 80.20047373, 90.100164  ,
#         99.99985427]),
#  <a list of 10 Patch objects>)

# %%
data=np.random.randn(10000)

# %%
data
# Out:
# array([-0.07027656,  0.3639322 , -0.31593858, ..., -0.36323341,
#         0.61745204,  1.80584442])

# %%
x = range(1,10001)
plt.plot(x, data)

# %%
# %matplotlib
plt.hist(data)
# Out:
# Using matplotlib backend: Qt5Agg
# (array([  25.,  162.,  771., 2010., 3031., 2527., 1138.,  300.,   31.,
#            5.]),
#  array([-3.69592315, -2.90660419, -2.11728523, -1.32796628, -0.53864732,
#          0.25067164,  1.0399906 ,  1.82930955,  2.61862851,  3.40794747,
#          4.19726642]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %%
mu = 5.5
sd= 2.5
Z_10000 = np.random.randn(10000)
data = 5.5 + 2.5 + sd* Z_10000 #z = (X-mu)/d -> N(0,1), X= mu = sd * Z

# %%
data
# Out:
# array([ 6.77785802, 11.53930065,  2.48369475, ...,  9.15513647,
#         4.73165717, 10.32242198])

# %%
data = np.random.randn(2,4)
data
# Out:
# array([[-1.35933446,  0.06892296,  1.33837616,  0.26810345],
#        [ 0.61123875,  1.11147487,  0.99718838, -0.08766249]])

# %% [markdown]
# # La simulacion de Monte Carlo

# %%
#Generamos dos nuemros aleatorios x entre 0 y1 
#Caq

# %% [markdown]
# Calculamos x * x + y*y
# si es menor a 1 esta adentro del circulo , si esta afuera es mas grande que 1
#
# Calcilamos el numero total de veces que esta adentro del circulo y lo dividimos entre el numero total de intetos par obtener una aproximacion de la probabilidad de caer dentro del ciruclo
# usamos dicha probabilidad para aproximar el valor de pi
# repetimos el expermiento un nuemro suficiente de veces ,para obrener diferenetes aproximacioens de pi
# CALCULAR UN PROMEDIO

# %% [markdown]
# def pi_montecarlo(n, n_exp)
#     pi_avg = 0
#     n=10000
#     pi_value_list = []
#     for i in range(n):
#         value = 0
#         x= np.random.uniform(0,1,n).tolist()
#         y= np.random.uniform(0,1,n).tolist()
#         for j in range (n):
#             z = np.sqrt(x[j] * x[j] + y[j] * y[j])
#             if z<=1 :
#                 value += 1
#
#         float_value = float(value)
#         pi_value = float_value * 4 /n
#         pi_value_list.append(pi_value)
#         pi_avg += pi_value
#
#
#     pi=pi_avg/1000
#
#     print(pi)
#     plt.plot(pi_value_list)
#
#     return

# %% [markdown]
# # Dummy Data sets

# %%
n = 1000
data= pd.DataFrame(
    {
       "A":np.random.randn(n),
        "B": 1.5 + 2.5 * np.random.randn(n),
        "C":np.random.uniform(5,32,n)
    }


)

data
# Out:
#             A         B          C
# 0   -0.126816  6.219252   5.464377
# 1   -1.055499  0.578218   6.323468
# 2   -0.539181  3.762683  12.517125
# 3    0.581953  0.207001  14.392446
# 4   -0.568845 -0.112065  30.877233
# ..        ...       ...        ...
# 995 -0.301914 -1.422843  23.090252
# 996  0.467285  1.441061  17.464296
# 997 -0.725318  1.401879  15.184908
# 998  0.482042 -3.423308  24.036969
# 999 -0.437959  2.152764  17.622927
#
# [1000 rows x 3 columns]

# %%
data.describe()
# Out:
#        Account Length    Area Code  VMail Message     Day Mins    Day Calls  \
# count     3333.000000  3333.000000    3333.000000  3333.000000  3333.000000
# mean       101.064806   437.182418       8.099010   179.775098   100.435644
# std         39.822106    42.371290      13.688365    54.467389    20.069084
# min          1.000000   408.000000       0.000000     0.000000     0.000000
# 25%         74.000000   408.000000       0.000000   143.700000    87.000000
# 50%        101.000000   415.000000       0.000000   179.400000   101.000000
# 75%        127.000000   510.000000      20.000000   216.400000   114.000000
# max        243.000000   510.000000      51.000000   350.800000   165.000000
#
#         Day Charge     Eve Mins    Eve Calls   Eve Charge   Night Mins  \
# count  3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean     30.562307   200.980348   100.114311    17.083540   200.872037
# ...

# %%
 pd.read_csv("../python-ml-course/datasets/customer-churn-model/Customer Churn Model.txt")
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
column_names = data.columns.values.tolist()
a = len(column_names)
a
# Out:
# 21

# %%
new_data = pd.DataFrame(
    {"Column Name": column_names,
     "A": 2.5  +3.7* np.random.randn(a),
     "B": np.random.uniform(4, 5, a)
    }



)

# %%
new_data
# Out:
#        Column Name          A         B
# 0            State   2.073159  4.258218
# 1   Account Length   6.670085  4.085202
# 2        Area Code   7.949009  4.333910
# 3            Phone   3.490531  4.726918
# 4       Int'l Plan  -0.340389  4.585934
# 5       VMail Plan   3.144151  4.739945
# 6    VMail Message   2.166887  4.203742
# 7         Day Mins   1.422049  4.041855
# 8        Day Calls   2.100933  4.671387
# 9       Day Charge   5.404821  4.944062
# 10        Eve Mins  -5.169182  4.906494
# 11       Eve Calls   0.936389  4.407698
# 12      Eve Charge   3.864647  4.645846
# 13      Night Mins   2.802279  4.305924
# 14     Night Calls   2.785346  4.308626
# 15    Night Charge   2.354632  4.124031
# 16       Intl Mins   0.025483  4.254214
# 17      Intl Calls   5.309758  4.532235
# 18     Intl Charge   8.106873  4.790823
# 19  CustServ Calls   2.092971  4.924511
# 20          Churn?  10.854262  4.345285
